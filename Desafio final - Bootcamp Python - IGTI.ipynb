# %%
# importando as bibliotecas
import numpy as np
import pandas as pd

# %%
# https://drive.google.com/file/d/1b9XiKXmVm_BkQvEn2LoB6sUGo0RH-KZs/view?usp=sharing#

# %%
dataset = pd.read_csv('/content/pima-indians-diabetes.csv', header=None)

# %%
dir(dataset)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       768 non-null    int64
#  1   1       768 non-null    int64
#  2   2       768 non-null    int64
#  3   3       768 non-null    int64
#  4   4       768 non-null    int64
#  5   5       768 non-null    float64
#  6   6       768 non-null    float64
#  7   7       768 non-null    int64
#  8   8       768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
dataset.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
dataset.tail()

# %%
dataset.isnull().any()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
dataset.isnull().sum()

# %%
dataset.isnull()

# %%
dataset.isnull().all()

# %%
dataset.describe()
# Out:
#                 0           1           2  ...           6           7           8
# count  768.000000  768.000000  768.000000  ...  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469  ...    0.471876   33.240885    0.348958
# std      3.369578   31.972618   19.355807  ...    0.331329   11.760232    0.476951
# min      0.000000    0.000000    0.000000  ...    0.078000   21.000000    0.000000
# 25%      1.000000   99.000000   62.000000  ...    0.243750   24.000000    0.000000
# 50%      3.000000  117.000000   72.000000  ...    0.372500   29.000000    0.000000
# 75%      6.000000  140.250000   80.000000  ...    0.626250   41.000000    1.000000
# max     17.000000  199.000000  122.000000  ...    2.420000   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
x = 3.0; len(dataset[dataset[0] <= x]), len(dataset), len(dataset[dataset[0] <= x]) / len(dataset)
# Out:
# (424, 768, 0.5520833333333334)

# %%
dataset[7]
# Out:
# 0      50
# 1      31
# 2      32
# 3      21
# 4      33
#        ..
# 763    63
# 764    27
# 765    30
# 766    47
# 767    23
# Name: 7, Length: 768, dtype: int64

# %%
dataset.shape

# %%
dir(dataset[0])

# %%
dataset[dataset[8] == 1][7].mean()
# Out:
# 37.06716417910448

# %%
max(dataset[dataset[8] == 0][0])
# Out:
# 13

# %%
# glicose = dataset[1]

df = pd. DataFrame({"Data1": [10, 20, 30], "Data2": [40, 50, 60]})
col_max = dataset[1].max()
normalized_df = dataset[1] / col_max
# print(normalized_df)
print(normalized_df.max())
# Out:
# 1.0

# %%
entradas = dataset[[0, 1, 2, 3, 4, 5, 6]]

# %%
entradas.head()
# Out:
#    0    1   2   3    4     5      6
# 0  6  148  72  35    0  33.6  0.627
# 1  1   85  66  29    0  26.6  0.351
# 2  8  183  64   0    0  23.3  0.672
# 3  1   89  66  23   94  28.1  0.167
# 4  0  137  40  35  168  43.1  2.288

# %%
entradas.size, entradas.ndim, entradas.shape, 768 * 8

# %%
from sklearn.preprocessing import MinMaxScaler
normaliza = MinMaxScaler() # objeto para a normalização

# %%
entradas_normalizadas = normaliza.fit_transform(entradas)

# %%
saida = dataset[8]

# %%
from sklearn.model_selection import train_test_split
entradas_treino, entradas_teste, saida_treino, saida_teste = train_test_split(entradas_normalizadas,
                                                                              saida, test_size=0.30,
                                                                              random_state=42)

# %%
entradas_treino.shape, entradas_normalizadas.shape, entradas.shape
# Out:
# ((537, 7), (768, 7), (768, 7))

# %%
saida_igual_um = saida[saida == 1]
saida_igual_zero = saida[saida == 0]

# %%
saida_igual_um.shape, saida_igual_zero.shape, saida.shape

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
entradas_treino, entradas_teste, saida_treino, saida_teste = train_test_split(entradas_normalizadas,
                                                                              saida, test_size=0.30,
                                                                              random_state=42)

from sklearn.neighbors import KNeighborsClassifier

clf_KNN = KNeighborsClassifier(n_neighbors=5)
clf_KNN.fit(entradas_treino, saida_treino)

#realiza a previsão com os dados
saida_prevista = clf_KNN.predict(entradas_teste)

print()
acuracia = accuracy_score(saida_teste, saida_prevista)
print('Acurácia KNN: ', acuracia)
# Out:
# Acurácia KNN:  0.6926406926406926

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
entradas_treino, entradas_teste, saida_treino, saida_teste = train_test_split(entradas_normalizadas,
                                                                              saida, test_size=0.30,
                                                                              random_state=42)

from sklearn.tree import DecisionTreeClassifier
clf_arvore = DecisionTreeClassifier(random_state=1)
clf_arvore.fit(entradas_treino, saida_treino)

#realiza a previsão com os dados
saida_prevista = clf_arvore.predict(entradas_teste)

print()
acuracia = accuracy_score(saida_teste, saida_prevista)
print('Acurácia arvore: ', acuracia)
# Out:
# Acurácia arvore:  0.6883116883116883

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
entradas_treino, entradas_teste, saida_treino, saida_teste = train_test_split(entradas_normalizadas,
                                                                              saida, test_size=0.30,
                                                                              random_state=42)

from sklearn.ensemble import RandomForestClassifier
clf_floresta = RandomForestClassifier(max_depth=10, random_state=1)
clf_floresta.fit(entradas_treino, saida_treino)

#realiza a previsão com os dados
saida_prevista = clf_floresta.predict(entradas_teste)

print()
acuracia = accuracy_score(saida_teste, saida_prevista)
print('Acurácia floresta: ', acuracia)
# Out:
# Acurácia floresta:  0.7532467532467533

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
entradas_treino, entradas_teste, saida_treino, saida_teste = train_test_split(entradas_normalizadas,
                                                                              saida, test_size=0.30,
                                                                              random_state=42)

from sklearn.svm import SVC
clf_svm = SVC(gamma='auto', random_state=1)
clf_svm.fit(entradas_treino, saida_treino)

#realiza a previsão com os dados
saida_prevista = clf_svm.predict(entradas_teste)

print()
acuracia = accuracy_score(saida_teste, saida_prevista)
print('Acurácia SVM: ', acuracia)
# Out:
# Acurácia SVM:  0.7878787878787878

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
entradas_treino, entradas_teste, saida_treino, saida_teste = train_test_split(entradas_normalizadas,
                                                                              saida, test_size=0.30,
                                                                              random_state=42)
from sklearn.neural_network import MLPClassifier
clf_mlp = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 10), random_state=1)
clf_mlp.fit(entradas_treino, saida_treino)

#realiza a previsão com os dados
saida_prevista = clf_mlp.predict(entradas_teste)

print()
acuracia = accuracy_score(saida_teste, saida_prevista)
print('Acurácia Redes Neurais MLP: ', acuracia)
# Out:
# Acurácia Redes Neurais MLP:  0.7445887445887446
